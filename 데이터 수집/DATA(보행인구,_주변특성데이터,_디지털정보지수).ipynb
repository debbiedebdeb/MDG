# %% [markdown]
# <a href="https://colab.research.google.com/github/debbiedebdeb/MDG/blob/master/Data_Preprocessing%20/%20DATA(%EB%B3%B4%ED%96%89%EC%9D%B8%EA%B5%AC%2C_%EC%A3%BC%EB%B3%80%ED%8A%B9%EC%84%B1%EB%8D%B0%EC%9D%B4%ED%84%B0%2C_%EB%94%94%EC%A7%80%ED%84%B8%EC%A0%95%EB%B3%B4%EC%A7%80%EC%88%98).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #보행인구 데이터 중 시니어 데이터만

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import numpy as np

# %%
# 1~3월 보행인구 파일불러오기
m13 = pd.read_csv('/content/drive/MyDrive/시소프로젝트/LG유플러스(데이터)/월 서울&6대 광역시 내국인의 요일,성별,연령대,시간대별 보행,비보행인구_220622_1-3.csv', encoding='cp949')
m13.head()
# Out:
#         월     시도  시군구 고객구분 요일 시간대  성별     연령대          보행인구        비보행인구
# 0  202101  광주광역시  광산구  내국인  금  야간  남성     10대  329977.94500  30854.78017
# 1  202101  광주광역시  광산구  내국인  금  야간  남성  10세 미만   21970.53535   1677.94367
# 2  202101  광주광역시  광산구  내국인  금  야간  남성     20대  199921.57420  56599.58540
# 3  202101  광주광역시  광산구  내국인  금  야간  남성     30대  154950.84220  63913.69369
# 4  202101  광주광역시  광산구  내국인  금  야간  남성     40대  213433.96440  86614.44267

# %%
# 4 ~ 6월 보행인구 파일불러오기
m46 = pd.read_csv('/content/drive/MyDrive/시소프로젝트/LG유플러스(데이터)/월 서울&6대 광역시 내국인의 요일,성별,연령대,시간대별 보행,비보행인구_220622_4-6.csv')
m46.head()
# Out:
#         월     시도  시군구 고객구분 요일 시간대  성별     연령대          보행인구          비보행인구
# 0  202104  광주광역시  광산구  내국인  금  야간  남성     10대  264047.54710   49697.223960
# 1  202104  광주광역시  광산구  내국인  금  야간  남성  10세 미만   28460.80326    3627.010242
# 2  202104  광주광역시  광산구  내국인  금  야간  남성     20대  159103.79040   70332.722290
# 3  202104  광주광역시  광산구  내국인  금  야간  남성     30대  133418.27000   77774.808750
# 4  202104  광주광역시  광산구  내국인  금  야간  남성     40대  178894.83700  107180.312300

# %%
# 7~9월 보행인구 파일불러오기
m79 = pd.read_csv('/content/drive/MyDrive/시소프로젝트/LG유플러스(데이터)/월 서울&6대 광역시 내국인의 요일,성별,연령대,시간대별 보행,비보행인구_220622_7-9.csv', encoding='cp949')
m79.head()
# Out:
#         월     시도  시군구 고객구분 요일 시간대  성별     연령대          보행인구          비보행인구
# 0  202107  광주광역시  광산구  내국인  금  야간  남성     10대  279185.93530   51318.328550
# 1  202107  광주광역시  광산구  내국인  금  야간  남성  10세 미만   34374.92334    4366.244027
# 2  202107  광주광역시  광산구  내국인  금  야간  남성     20대  192662.17050   74182.544910
# 3  202107  광주광역시  광산구  내국인  금  야간  남성     30대  152402.77550   76796.027120
# 4  202107  광주광역시  광산구  내국인  금  야간  남성     40대  205017.34520  108716.278200

# %%
# 10~12월 보행인구 파일불러오기
m1012 = pd.read_csv('/content/drive/MyDrive/시소프로젝트/LG유플러스(데이터)/월 서울&6대 광역시 내국인의 요일,성별,연령대,시간대별 보행,비보행인구_220622_10-12.csv', encoding='cp949')
m1012.head()
# Out:
#         월     시도  시군구 고객구분 요일 시간대  성별     연령대          보행인구          비보행인구
# 0  202110  광주광역시  광산구  내국인  금  야간  남성     10대  332711.08450   61681.134790
# 1  202110  광주광역시  광산구  내국인  금  야간  남성  10세 미만   42084.36396    4901.709235
# 2  202110  광주광역시  광산구  내국인  금  야간  남성     20대  214515.57810   77731.712540
# 3  202110  광주광역시  광산구  내국인  금  야간  남성     30대  177000.74500   80761.334420
# 4  202110  광주광역시  광산구  내국인  금  야간  남성     40대  245992.57550  116424.265500

# %% [markdown]
# ## 서울특별시와 60, 70대만 남긴 후 합치기

# %%
# 1년치 보행인구 파일 만들기 
seoul2021 = pd.concat([m13, m46, m79, m1012], ignore_index=True)
seoul2021
# Out:
#              월     시도  시군구 고객구분 요일 시간대  성별     연령대          보행인구        비보행인구
# 0       202101  광주광역시  광산구  내국인  금  야간  남성     10대  329977.94500  30854.78017
# 1       202101  광주광역시  광산구  내국인  금  야간  남성  10세 미만   21970.53535   1677.94367
# 2       202101  광주광역시  광산구  내국인  금  야간  남성     20대  199921.57420  56599.58540
# 3       202101  광주광역시  광산구  내국인  금  야간  남성     30대  154950.84220  63913.69369
# 4       202101  광주광역시  광산구  내국인  금  야간  남성     40대  213433.96440  86614.44267
# ...        ...    ...  ...  ... ..  ..  ..     ...           ...          ...
# 298350  202112  인천광역시   중구  내국인  화  주간  여성     30대   84203.44246  62339.29754
# 298351  202112  인천광역시   중구  내국인  화  주간  여성     40대   97186.94874  69603.23587
# 298352  202112  인천광역시   중구  내국인  화  주간  여성     50대   77667.70214  66258.66446
# 298353  202112  인천광역시   중구  내국인  화  주간  여성     60대   66662.23536  48342.33616
# 298354  202112  인천광역시   중구  내국인  화  주간  여성  70세 이상   56822.87493  26231.91521
#
# [298355 rows x 10 columns]

# %%
# 서울시만 출력
seoul2021 = seoul2021[seoul2021['시도'] == '서울특별시']
seoul2021
# Out:
#              월     시도  시군구 고객구분 요일 시간대  성별     연령대           보행인구  \
# 11424   202101  서울특별시  강남구  내국인  금  야간  남성     10대  222676.773100
# 11425   202101  서울특별시  강남구  내국인  금  야간  남성  10세 미만    5839.103368
# 11426   202101  서울특별시  강남구  내국인  금  야간  남성     20대  140010.518700
# 11427   202101  서울특별시  강남구  내국인  금  야간  남성     30대  140182.743500
# 11428   202101  서울특별시  강남구  내국인  금  야간  남성     40대  195300.725500
# ...        ...    ...  ...  ... ..  ..  ..     ...            ...
# 293310  202112  서울특별시  중랑구  내국인  화  주간  여성     30대  186737.290400
# 293311  202112  서울특별시  중랑구  내국인  화  주간  여성     40대  209443.743100
# 293312  202112  서울특별시  중랑구  내국인  화  주간  여성     50대  267545.685600
# 293313  202112  서울특별시  중랑구  내국인  화  주간  여성     60대  250740.449500
# 293314  202112  서울특별시  중랑구  내국인  화  주간  여성  70세 이상  204827.916700
#
#                 비보행인구
# 11424    14450.782170
# 11425      378.404066
# 11426    32129.973220
# 11427    59761.499580
# 11428    85245.372670
# ...               ...
# ...

# %%
# 60대 이상만 출력
seoul6070 = seoul2021[seoul2021['연령대'].isin(['60대', '70대', '70세 이상'])]
seoul6070
# Out:
#              월     시도  시군구 고객구분 요일 시간대  성별     연령대          보행인구  \
# 11430   202101  서울특별시  강남구  내국인  금  야간  남성     60대  126197.06870
# 11431   202101  서울특별시  강남구  내국인  금  야간  남성  70세 이상   95732.66964
# 11438   202101  서울특별시  강남구  내국인  금  야간  여성     60대  136578.19650
# 11439   202101  서울특별시  강남구  내국인  금  야간  여성  70세 이상  108674.61800
# 11446   202101  서울특별시  강남구  내국인  금  저녁  남성     60대  149791.42860
# ...        ...    ...  ...  ... ..  ..  ..     ...           ...
# 293298  202112  서울특별시  중랑구  내국인  화  저녁  여성  70세 이상   86453.32568
# 293305  202112  서울특별시  중랑구  내국인  화  주간  남성     60대  200841.14620
# 293306  202112  서울특별시  중랑구  내국인  화  주간  남성  70세 이상  146322.05620
# 293313  202112  서울특별시  중랑구  내국인  화  주간  여성     60대  250740.44950
# 293314  202112  서울특별시  중랑구  내국인  화  주간  여성  70세 이상  204827.91670
#
#                 비보행인구
# 11430    64479.718460
# 11431    27693.090440
# 11438    28646.269250
# 11439    18567.962330
# 11446    82482.840800
# ...               ...
# ...

# %%
seoul6070.reset_index(drop=True, inplace=True)
seoul6070
# Out:
#             월     시도  시군구 고객구분 요일 시간대  성별     연령대          보행인구          비보행인구
# 0      202101  서울특별시  강남구  내국인  금  야간  남성     60대  126197.06870   64479.718460
# 1      202101  서울특별시  강남구  내국인  금  야간  남성  70세 이상   95732.66964   27693.090440
# 2      202101  서울특별시  강남구  내국인  금  야간  여성     60대  136578.19650   28646.269250
# 3      202101  서울특별시  강남구  내국인  금  야간  여성  70세 이상  108674.61800   18567.962330
# 4      202101  서울특별시  강남구  내국인  금  저녁  남성     60대  149791.42860   82482.840800
# ...       ...    ...  ...  ... ..  ..  ..     ...           ...            ...
# 25195  202112  서울특별시  중랑구  내국인  화  저녁  여성  70세 이상   86453.32568    9348.223405
# 25196  202112  서울특별시  중랑구  내국인  화  주간  남성     60대  200841.14620  129691.065300
# 25197  202112  서울특별시  중랑구  내국인  화  주간  남성  70세 이상  146322.05620   61586.558390
# 25198  202112  서울특별시  중랑구  내국인  화  주간  여성     60대  250740.44950   99599.313470
# 25199  202112  서울특별시  중랑구  내국인  화  주간  여성  70세 이상  204827.91670   53073.867870
#
# ...

# %%
# 주민센터 및 복지관의 시설 이용시간은 주간대이기 때문에, "주간"데이터만 추출
seoul6070 = seoul6070[seoul6070['시간대']=='주간']

# %%
seoul6070 = seoul6070.sort_values(by=['보행인구'], ascending=False)

# %%
seoul6070[seoul6070['요일'].isin(['월', '화', '수', '목', '금'])]
# Out:
#             월     시도  시군구 고객구분 요일 시간대  성별     연령대          보행인구         비보행인구
# 20338  202110  서울특별시  송파구  내국인  금  주간  여성     60대  539345.16390  181619.77190
# 18250  202109  서울특별시  송파구  내국인  목  주간  여성     60대  535912.87060  176526.35430
# 7738   202104  서울특별시  송파구  내국인  금  주간  여성     60대  532652.59920  173382.56850
# 7750   202104  서울특별시  송파구  내국인  목  주간  여성     60대  531849.50720  174279.47360
# 22474  202111  서울특별시  송파구  내국인  월  주간  여성     60대  518695.83420  207691.26440
# ...       ...    ...  ...  ... ..  ..  ..     ...           ...           ...
# 669    202101  서울특별시  금천구  내국인  화  주간  남성  70세 이상   78986.68922   42345.56317
# 10929  202106  서울특별시  광진구  내국인  금  주간  남성  70세 이상   76381.71835   44065.10800
# 609    202101  서울특별시  금천구  내국인  목  주간  남성  70세 이상   74986.65756   39231.19486
# 12189  202106  서울특별시  용산구  내국인  금  주간  남성  70세 이상   71462.93070   55379.87449
# 11097  202106  서울특별시  금천구  내국인  금  주간  남성  70세 이상   67416.19354   31139.63600
#
# [6000 rows x 10 columns]

# %%
seoul6070.reset_index(drop=True, inplace=True)
seoul6070
# seoul6070.to_csv('seoul6070.csv', index=None)
# Out:
#            월     시도  시군구 고객구분 요일 시간대  성별     연령대          보행인구         비보행인구
# 0     202110  서울특별시  송파구  내국인  금  주간  여성     60대  539345.16390  181619.77190
# 1     202109  서울특별시  송파구  내국인  목  주간  여성     60대  535912.87060  176526.35430
# 2     202104  서울특별시  송파구  내국인  금  주간  여성     60대  532652.59920  173382.56850
# 3     202104  서울특별시  송파구  내국인  목  주간  여성     60대  531849.50720  174279.47360
# 4     202111  서울특별시  송파구  내국인  월  주간  여성     60대  518695.83420  207691.26440
# ...      ...    ...  ...  ... ..  ..  ..     ...           ...           ...
# 8395  202103  서울특별시  용산구  내국인  토  주간  남성  70세 이상   67282.46319   52127.64982
# 8396  202103  서울특별시  금천구  내국인  토  주간  여성  70세 이상   65720.30654   23166.55849
# 8397  202107  서울특별시   중구  내국인  일  주간  남성  70세 이상   62522.98170   34852.99897
# 8398  202103  서울특별시   중구  내국인  토  주간  남성  70세 이상   62257.92606   43988.23912
# 8399  202103  서울특별시  금천구  내국인  토  주간  남성  70세 이상   53599.83762   27464.05339
#
# [8400 rows x 10 columns]

# %%
seoul6070 = seoul6070.drop(columns=['시도', '고객구분', '시간대', '성별', '비보행인구'])
seoul6070
# Out:
#            월  시군구 요일     연령대          보행인구
# 0     202110  송파구  금     60대  539345.16390
# 1     202109  송파구  목     60대  535912.87060
# 2     202104  송파구  금     60대  532652.59920
# 3     202104  송파구  목     60대  531849.50720
# 4     202111  송파구  월     60대  518695.83420
# ...      ...  ... ..     ...           ...
# 8395  202103  용산구  토  70세 이상   67282.46319
# 8396  202103  금천구  토  70세 이상   65720.30654
# 8397  202107   중구  일  70세 이상   62522.98170
# 8398  202103   중구  토  70세 이상   62257.92606
# 8399  202103  금천구  토  70세 이상   53599.83762
#
# [8400 rows x 5 columns]

# %%
# 평균값
one = seoul6070.groupby(by=['월','시군구']).sum().unstack().mean().to_frame()
one
# Out:
#                       0
#      시군구
# 보행인구 강남구   8.742670e+06
#      강동구   6.345216e+06
#      강북구   4.421889e+06
#      강서구   7.388629e+06
#      관악구   5.847915e+06
#      광진구   4.154235e+06
#      구로구   6.019903e+06
#      금천구   3.583914e+06
#      노원구   7.270581e+06
#      도봉구   4.803348e+06
#      동대문구  6.191491e+06
#      동작구   5.378581e+06
#      마포구   4.653901e+06
#      서대문구  4.405539e+06
#      서초구   6.666429e+06
#      성동구   4.282231e+06
#      성북구   5.578754e+06
#      송파구   9.120939e+06
#      양천구   5.450672e+06
#      영등포구  6.533197e+06
#      용산구   3.694697e+06
#      은평구   6.167004e+06
#      종로구   4.474791e+06
#      중구    3.983876e+06
#      중랑구   5.952526e+06

# %% [markdown]
# #변수 : 인구특성

# %%
# 행정동 인구특성 데이터 가져오기 
people = pd.read_excel('/content/drive/MyDrive/시소프로젝트/NEW(공모전용)/전처리용/인구특성.xlsx')
people1= people.iloc[:,:2]

# %%
people.head()
# 60/(행정동)전체인구 : 각 행정동의 60세 이상 비율 
# 구별 전체 : 행정구 기준 60세 이상 인구수 
# 동별60~ / 구별60~ : 행정동별 60세 이상 비율
# Out:
#      구    동   0~4세   5~9세  10~14세  15~19세  20~24세  25~29세  30~34세  35~39세  \
# 0  종로구  사직동  202.0  356.0   342.0   333.0   465.0   737.0   769.0   678.0
# 1  종로구  삼청동   37.0   65.0    87.0    84.0   144.0   176.0   148.0   155.0
# 2  종로구  부암동  165.0  332.0   401.0   453.0   584.0   643.0   602.0   608.0
# 3  종로구  평창동  454.0  694.0   760.0   819.0  1104.0  1238.0  1032.0  1168.0
# 4  종로구  무악동  243.0  402.0   500.0   476.0   467.0   440.0   377.0   526.0
#
#    ...  80~84세  85~89세  90~94세  95~99세  100세 이상   전체인구   60~  60~/전체인구  구별 전체  \
# 0  ...   309.0   167.0    62.0    22.0      1.0   9372  2468  0.263338  39120
# 1  ...    87.0    60.0    20.0     6.0      2.0   2456   827  0.336726  39120
# 2  ...   265.0   131.0    60.0    13.0      3.0   9579  2558  0.267042  39120
# 3  ...   505.0   285.0   121.0    38.0      6.0  18152  4937  0.271981  39120
# 4  ...   234.0    97.0    30.0    10.0      3.0   8259  2006  0.242887  39120
#
#    동별 60~ / 구별 60~
# 0         0.063088
# ...

# %%
people2 = people.iloc[:,23:]

# %%
people =pd.concat([people1,people2], axis=1)
people.head()
# Out:
#      구    동   전체인구   60~  60~/전체인구  구별 전체  동별 60~ / 구별 60~
# 0  종로구  사직동   9372  2468  0.263338  39120         0.063088
# 1  종로구  삼청동   2456   827  0.336726  39120         0.021140
# 2  종로구  부암동   9579  2558  0.267042  39120         0.065389
# 3  종로구  평창동  18152  4937  0.271981  39120         0.126201
# 4  종로구  무악동   8259  2006  0.242887  39120         0.051278

# %%
people.columns = ['시군구', '동', '동별전체인구', '60세~', '60세~/전체인구', '구별전체인구', '60세~/구별전체']

# %%
people.head()
# Out:
#    시군구    동  동별전체인구  60세~  60세~/전체인구  구별전체인구  60세~/구별전체
# 0  종로구  사직동    9372  2468   0.263338   39120   0.063088
# 1  종로구  삼청동    2456   827   0.336726   39120   0.021140
# 2  종로구  부암동    9579  2558   0.267042   39120   0.065389
# 3  종로구  평창동   18152  4937   0.271981   39120   0.126201
# 4  종로구  무악동    8259  2006   0.242887   39120   0.051278

# %%
#유동인구와 merge 하기
people = pd.merge(people, one, how = 'inner', on='시군구')

# %%
people.columns = ['시군구', '동', '동별전체인구', '60세~', '60세~/전체인구', '구별전체인구', '60세~/구별전체', '보행인구']
people['비율'] = None
people['비율'] = people['60세~/구별전체'] * people['보행인구'] # 행정동별 시니어 인구비율 * 보행인구

# %%
people
# Out:
#      시군구     동  동별전체인구   60세~  60세~/전체인구  구별전체인구  60세~/구별전체          보행인구  \
# 0    종로구   사직동    9372   2468   0.263338   39120   0.063088  4.474791e+06
# 1    종로구   삼청동    2456    827   0.336726   39120   0.021140  4.474791e+06
# 2    종로구   부암동    9579   2558   0.267042   39120   0.065389  4.474791e+06
# 3    종로구   평창동   18152   4937   0.271981   39120   0.126201  4.474791e+06
# 4    종로구   무악동    8259   2006   0.242887   39120   0.051278  4.474791e+06
# ..   ...   ...     ...    ...        ...     ...        ...           ...
# 420  강동구  둔촌2동   24661   6259   0.253802  111309   0.056231  6.345216e+06
# 421  강동구  암사1동   34486   9021   0.261584  111309   0.081045  6.345216e+06
# 422  강동구  천호2동   33154   8694   0.262231  111309   0.078107  6.345216e+06
# 423  강동구    길동   45653  12152   0.266182  111309   0.109174  6.345216e+06
# 424  강동구  상일1동   38834   7184   0.184993  111309   0.064541  6.345216e+06
#
#                 비율
# 0    282305.293147
# 1     94597.438184
# ...

# %% [markdown]
# #변수 : 디지털정보지수

# %% [markdown]
# * 디지털 정보 지수 : 일반국민의 디지털정보화 수준을 100으로 할때, 일반국민 대비 연령별 디지털 정보화 역량수준 (과학기술정보통신부 2021)
# * 100 이하인 50대, 60대, 70세 이상 의 디지털정보지수를 변수로 설정

# %%
# 파일 불러오기 
media = pd.read_excel('/content/drive/MyDrive/시소프로젝트/완성데이터/원천 데이터(데이터 가공 전)/동별_연령대별_인구_from 서울시열린데이터.xlsx')
media[:4]
# Out:
#      동 0~4세  5~9세  10~14세  15~19세  19세미만   20~24세  25~29세   20대  30~34세  ...  \
# 0  사직동  194   352     345     342    1233     461     728  1189     772  ...
# 1  삼청동   34    60      89      82     265     134     175   309     159  ...
# 2  부암동  149   327     384     466    1326     576     627  1203     591  ...
# 3  평창동  459   687     765     801    2712    1081    1212  2293    1042  ...
#
#    55~59세   50대  60~64세  65~69세   60대  70~74세  75~79세  80~84세  85~89세  70세 이상
# 0     707  1542     719     503  1222     359     344     306     168    1177
# 1     183   379     224     190   414     133     103      90      61     387
# 2     793  1682     741     585  1326     409     330     265     139    1143
# 3    1560  3258    1518    1191  2709     717     586     507     286    2096
#
# [4 rows x 26 columns]

# %%
#불필요한 컬럼 삭제 
media.drop(columns = ['0~4세', '5~9세', '10~14세', '15~19세',
                     '20~24세', '25~29세','30~34세', '35~39세','40~44세', '45~49세',
                      '50~54세', '55~59세',  '60~64세', '65~69세','70~74세', '75~79세', '80~84세', '85~89세'], inplace = True)

# %%
#역량수준 리스트 생성 
dgt_level = [0.92,0.593,0.224]

#역량수준 * 인구 수 곱 
result = round(media.iloc[:,5:]*dgt_level,2)

# %%
media_df = pd.concat([media[['동']],result], axis = 1)
media_df['디지털정보지수'] = media_df.sum(axis =1)
media_df
final_df = media_df[['동','디지털정보지수']]
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.

# %%
media_df
# Out:
#         동      50대      60대   70세 이상   디지털정보지수
# 0     사직동  1418.64   724.65   263.65   2406.94
# 1     삼청동   348.68   245.50    86.69    680.87
# 2     부암동  1547.44   786.32   256.03   2589.79
# 3     평창동  2997.36  1606.44   469.50   5073.30
# 4     무악동  1309.16   624.43   212.35   2145.94
# ..    ...      ...      ...      ...       ...
# 420  천호2동  4861.28  2986.35   813.79   8661.42
# 421    길동  6677.36  4372.19  1066.46  12116.01
# 422   강일동  4359.88  2757.45   702.24   7819.57
# 423   상일동  6377.44  3585.28   729.57  10692.29
# 424  상일2동  1393.80   640.44   212.80   2247.04
#
# [425 rows x 5 columns]

# %%
# # 저장 
# final_df.to_csv('동별 디지털정보지수(50~).csv')
# final_df.to_excel('동별 디지털정보지수(50~).xlsx')

# %% [markdown]
# ** 신사동이 2곳이라 추후 merge작업할때 행이 늘어날 수 있다

# %% [markdown]
# # 위경도를 통한 주변특성 데이터 구하기

# %% [markdown]
# ## 주민센터 및 복지관 위경도 가져오기

# %% [markdown]
# * 주소를 이용해 위도, 경도를 가져옵니다
# * 지오코딩 이용

# %%
# !pip install geopy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
from geopy.geocoders import Nominatim

# %%
df = pd.read_csv('/content/drive/MyDrive/시소프로젝트/NEW(공모전용)/전처리용/연면적.csv')
df.head(1)
# Out:
#    자치구      동         시설명                 주소     연면적
# 0  종로구  청운효자동  청운효자동 주민센터  서울특별시 종로구 자하문로 92  965.52

# %%
geolocoder = Nominatim(user_agent = 'South Korea', timeout = None)

def geocoding(address) : 
    try : 
        geo= geolocoder.geocode(address)
        crd = (str(geo.latitude), str(geo.longitude))
        return crd
    
    except : 
        return (0,0)

# %%
lats = []
logs = []

for address in df['주소'] : 
    crd = geocoding(address)
    lats.append(crd[0])
    logs.append(crd[1])

lats = pd.Series(lats)
logs = pd.Series(logs)

# %%
df = pd.concat([df, lats], axis = 1)
df = pd.concat([df, logs], axis = 1)
df.head(5)
# Out:
#    자치구            동           시설명                 주소      연면적  \
# 0  종로구        청운효자동    청운효자동 주민센터  서울특별시 종로구 자하문로 92   965.52
# 1  종로구          사직동      사직동 주민센터  서울특별시 종로구 사직로9길 1   346.65
# 2  종로구  종로1.2.3.4가동  종로1-4가동 주민센터  서울특별시 종로구 종로17길 8  1981.09
# 3  종로구          삼청동      삼청동 주민센터  서울특별시 종로구 삼청로 107    998.1
# 4  종로구          가회동      가회동 주민센터   서울특별시 종로구 북촌로 35  1032.08
#
#                     0                   0
# 0          37.5840835         126.9706357
# 1  37.576191449999996        126.96882915
# 2          37.5707276         126.9889123
# 3          37.5849793  126.98178162729107
# 4         37.58002545  126.98480464831948

# %%
df.columns = ['자치구', '동', '시설명', '주소', '연면적', '위도', '경도']

# %%
# 변환되지 않은 관측치들 확인 
df[df['위도']==0]
# Out:
#       자치구     동        시설명                      주소       연면적 위도 경도
# 115   성북구   안암동   안암동 주민센터        서울특별시 성북구 인촌로 16   2226.53  0  0
# 238   양천구  신정6동  신정6동 주민센터        서울특별시 양천구 신남3길 6    1096.3  0  0
# 274   구로구   수궁동   수궁동 주민센터     서울특별시 구로구 오리로15길 32    863.22  0  0
# 276   금천구  독산1동  독산1동 주민센터   서울특별시 금천구 시흥대로123길 11   3086.62  0  0
# 277   금천구  독산2동  독산2동 주민센터      서울특별시 금천구 범안로 1240  2,923.86  0  0
# 291  영등포구   문래동   문래동 주민센터    서울특별시 영등포구 문래로28길 15  1,001.40  0  0
# 292  영등포구  양평1동  양평1동 주민센터   서울특별시 영등포구 영등포로11길 12    693.89  0  0
# 293  영등포구  양평2동  양평2동 주민센터   서울특별시 영등포구 양평로20길 8-1    451.62  0  0
# 439   중랑구   중화동    중화경로복지관     서울특별시중랑구 동일로138길 28       753  0  0
# 476   강서구   화곡동  연지어르신복지센터  서울특별시 강서구 화곡로 58길 30-7       796  0  0
# 496   강남구   역삼동   역삼노인복지센터       서울특별시 강남구 도곡로길 27     1,030  0  0
# 508   성동구   용답동    삼성시니어센터   서울특별시 성동구 용답중앙11다길 22   1716.38  0  0

# %%
# 주소는 제대로 되어있다. GMAP에서 찾아 직접 넣어주기 
df.iloc[115, 5]= 37.5858
df.iloc[115, 6]= 127.0214

# %%
df.iloc[238, 3]= '서울특별시 양천구 목동서로 353'
df.iloc[238, 5]= 37.5171
df.iloc[238, 6]= 126.8645

# %%
df.iloc[274, 5]= 37.4939
df.iloc[274, 6]= 126.8315

df.iloc[439, 5]= 37.6033
df.iloc[439, 6]= 127.0812


df.iloc[476, 5]= 37.5524
df.iloc[476, 6]= 126.8526

df.iloc[496, 3]= '서울특별시 강남구 역삼2동 781-34'
df.iloc[496, 5]= 37.4945
df.iloc[496, 6]= 127.0418

df.iloc[508, 3]= '서울특별시 성동구 용답동 72-17'
df.iloc[508, 5]= 37.5658
df.iloc[508, 6]= 127.0525

# %%
# 확인작업 
df[df['위도']==0] # 위도 경도 모두 변환 완료
# Out:
#       자치구     동        시설명                     주소       연면적 위도 경도
# 276   금천구  독산1동  독산1동 주민센터  서울특별시 금천구 시흥대로123길 11   3086.62  0  0
# 277   금천구  독산2동  독산2동 주민센터     서울특별시 금천구 범안로 1240  2,923.86  0  0
# 291  영등포구   문래동   문래동 주민센터   서울특별시 영등포구 문래로28길 15  1,001.40  0  0
# 292  영등포구  양평1동  양평1동 주민센터  서울특별시 영등포구 영등포로11길 12    693.89  0  0
# 293  영등포구  양평2동  양평2동 주민센터  서울특별시 영등포구 양평로20길 8-1    451.62  0  0

# %%
df.head()
# Out:
#    자치구            동           시설명                 주소      연면적  \
# 0  종로구        청운효자동    청운효자동 주민센터  서울특별시 종로구 자하문로 92   965.52
# 1  종로구          사직동      사직동 주민센터  서울특별시 종로구 사직로9길 1   346.65
# 2  종로구  종로1.2.3.4가동  종로1-4가동 주민센터  서울특별시 종로구 종로17길 8  1981.09
# 3  종로구          삼청동      삼청동 주민센터  서울특별시 종로구 삼청로 107    998.1
# 4  종로구          가회동      가회동 주민센터   서울특별시 종로구 북촌로 35  1032.08
#
#                    위도                  경도
# 0          37.5840835         126.9706357
# 1  37.576191449999996        126.96882915
# 2          37.5707276         126.9889123
# 3          37.5849793  126.98178162729107
# 4         37.58002545  126.98480464831948

# %%
#저장
# df.to_excel('데이터위도경도포함.xlsx')

# %% [markdown]
# ## 주민센터 위경도에 UTMK 추가

# %%
# !pip install pyproj
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 6.3 MB 12.8 MB/s
# ...

# %%
import pandas as pd
import numpy as np
import pyproj
from pyproj import Transformer

# %%
main = pd.read_excel('/content/drive/MyDrive/시소프로젝트/NEW(공모전용)/전처리용/데이터위도경도포함.xlsx',index_col=0)
main.head(1)
# Out:
#      자치구      동         시설명                 주소     연면적         위도          경도
# 0.0  종로구  청운효자동  청운효자동 주민센터  서울특별시 종로구 자하문로 92  965.52  37.584083  126.970636

# %%
# 서울역 위도 경도 (37.553230, 126.972551) (예시)
transformer = Transformer.from_crs("epsg:4326", "epsg:5178")
transformer.transform(37.553230, 126.972551)
# Out:
# (1950256.3879044417, 953600.9747718363)

# %%
# transformer.transform(37.560927, 127.193877)
list1 = []
for i in range(0, len(main)):
    list1.append(transformer.transform(main['위도'][i], main['경도'][i]))

list1
# Out:
# [(1953680.4107067548, 953451.0305672353),
#  (1952805.7150767343, 953286.5880716629),
#  (1952189.7125275738, 955056.6789118368),
#  (1953774.3237514026, 954435.6795061529),
#  (1953223.248442944, 954699.5803852201),
#  (1952327.4588193654, 956483.9647044425),
#  (1952875.5529025472, 956420.6357743395),
#  (1953970.565093043, 956098.4625721083),
#  (1952829.6012131637, 957408.6513756055),
#  (1953145.276968142, 956874.0448127431),
#  (1952829.6012131637, 957408.6513756055),
#  (1952829.6012131637, 957408.6513756055),
#  (1952732.1914813584, 957802.5274845127),
#  (1952330.4399108805, 952675.5729051178),
#  (1956152.3522304904, 953258.8070320927),
#  (1954369.3167579314, 953453.7461930809),
#  (1952786.0967898367, 952346.0677775362),
#  (1951327.7279225483, 954026.6687767816),
#  (1950706.6244977568, 954198.7293203992),
#  (1951005.4741406671, 954779.2664321188),
#  (1951051.0375977478, 955569.7448418225),
#  (1951201.9229545821, 956713.4114992636),
# ...

# %%
df = pd.DataFrame(list1)
df.columns = ['위도UTMK', '경도UTMK']
df
# Out:
#            위도UTMK         경도UTMK
# 0    1.953680e+06  953451.030567
# 1    1.952806e+06  953286.588072
# 2    1.952190e+06  955056.678912
# 3    1.953774e+06  954435.679506
# 4    1.953223e+06  954699.580385
# ..            ...            ...
# 504  1.949452e+06  967593.315153
# 505  1.954203e+06  957275.933852
# 506  1.939588e+06  946023.287446
# 507  1.941835e+06  954896.456135
# 508  1.951614e+06  960669.395691
#
# [509 rows x 2 columns]

# %%
main0 = pd.concat([main, df], axis=1)
main0
# Out:
#        자치구            동           시설명                        주소      연면적  \
# 0.0    종로구        청운효자동    청운효자동 주민센터         서울특별시 종로구 자하문로 92   965.52
# 1.0    종로구          사직동      사직동 주민센터         서울특별시 종로구 사직로9길 1   346.65
# 2.0    종로구  종로1.2.3.4가동  종로1-4가동 주민센터         서울특별시 종로구 종로17길 8  1981.09
# 3.0    종로구          삼청동      삼청동 주민센터         서울특별시 종로구 삼청로 107    998.1
# 4.0    종로구          가회동      가회동 주민센터          서울특별시 종로구 북촌로 35  1032.08
# ...    ...          ...           ...                       ...      ...
# 504.0  강동구         천호2동       해공노인복지관    서울특별시 강동구 천중로17길 42-16      598
# 505.0  성북구          삼선동      삼선실버복지센터      서울특별시 성북구 삼선교로18길 41   542.11
# 506.0  금천구         독산1동   금천한내어르신복지센터       서울특별시 금천구 한내로 69-15     2003
# 507.0  서초구         방배3동      방배느티나무쉼터  서울특별시 서초구 남부순환로287길 17-4    519.5
# 508.0  성동구          용답동       삼성시니어센터       서울특별시 성동구 용답동 72-17  1716.38
#
#               위도          경도        위도UTMK         경도UTMK
# ...

# %%
main = main0

# %% [markdown]
# ## 주변특성 개수 찾기 시작

# %%
# 도서관 UTMK 위경도 데이터 불러오기
library = pd.read_excel('/content/drive/MyDrive/시소프로젝트/NEW(공모전용)/대중교통, 주변특성 데이터/공공도서관 위도경도 변환.xlsx',index_col =0)
library = library.iloc[:,13:15]
library.head(1)
# Out:
#          위도UTMK         경도UTMK
# 0  1.941139e+06  964517.755038

# %%
x = main['위도UTMK']
x.head(1)
# Out:
# 0.0    1.953680e+06
# Name: 위도UTMK, dtype: float64

# %%
y = main['경도UTMK']
y.head(1)
# Out:
# 0.0    953451.030567
# Name: 경도UTMK, dtype: float64

# %%
a1 = library['위도UTMK']
a1.head(1)
# Out:
# 0    1.941139e+06
# Name: 위도UTMK, dtype: float64

# %%
a2 = library['경도UTMK']
a2.head(1)
# Out:
# 0    964517.755038
# Name: 경도UTMK, dtype: float64

# %%
main["도서관(500)"] = 0
main.head(1)
# Out:
#      자치구      동         시설명                 주소     연면적         위도          경도  \
# 0.0  종로구  청운효자동  청운효자동 주민센터  서울특별시 종로구 자하문로 92  965.52  37.584083  126.970636
#
#            위도UTMK         경도UTMK  도서관(500)
# 0.0  1.953680e+06  953451.030567         0

# %%
# 반경 500m 내의 도서관 개수 찾기 
for i in range(len(main)):
    for j in range(len(library)):
        value = False
        value = np.sqrt((x[i] - a1[j])**2 + (y[i] - a2[j])**2) <= 500
        if value == True:
            main['도서관(500)'][i] += int(value)
        else:
            pass
main
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#        자치구            동           시설명                        주소      연면적  \
# 0.0    종로구        청운효자동    청운효자동 주민센터         서울특별시 종로구 자하문로 92   965.52
# 1.0    종로구          사직동      사직동 주민센터         서울특별시 종로구 사직로9길 1   346.65
# 2.0    종로구  종로1.2.3.4가동  종로1-4가동 주민센터         서울특별시 종로구 종로17길 8  1981.09
# 3.0    종로구          삼청동      삼청동 주민센터         서울특별시 종로구 삼청로 107    998.1
# 4.0    종로구          가회동      가회동 주민센터          서울특별시 종로구 북촌로 35  1032.08
# ...    ...          ...           ...                       ...      ...
# 504.0  강동구         천호2동       해공노인복지관    서울특별시 강동구 천중로17길 42-16      598
# 505.0  성북구          삼선동      삼선실버복지센터      서울특별시 성북구 삼선교로18길 41   542.11
# ...

# %%
#배움터 시설 UTMK 데이터 가져오기
academy = pd.read_excel('/content/drive/MyDrive/시소프로젝트/NEW(공모전용)/대중교통, 주변특성 데이터/배움터 위도경도 변환.xlsx',index_col =0)
academy.head(1)
# Out:
#           위도          경도        위도UTMK        경도UTMK
# 0  37.577213  127.006909  1.952901e+06  956649.72721

# %%
a1 = academy['위도UTMK']
a1.head(1)
# Out:
# 0    1.952901e+06
# Name: 위도UTMK, dtype: float64

# %%
a2 = academy['경도UTMK']
a2.head(1)
# Out:
# 0    956649.72721
# Name: 경도UTMK, dtype: float64

# %%
main["배움터(500)"] = 0
main.head(2)
# Out:
#      자치구      동         시설명                 주소     연면적         위도          경도  \
# 0.0  종로구  청운효자동  청운효자동 주민센터  서울특별시 종로구 자하문로 92  965.52  37.584083  126.970636
# 1.0  종로구    사직동    사직동 주민센터  서울특별시 종로구 사직로9길 1  346.65  37.576191  126.968829
#
#            위도UTMK         경도UTMK  도서관(500)  배움터(500)
# 0.0  1.953680e+06  953451.030567         0         0
# 1.0  1.952806e+06  953286.588072         2         0

# %%
for i in range(len(main)):
    for j in range(len(academy)):
        value = False
        value = np.sqrt((x[i] - a1[j])**2 + (y[i] - a2[j])**2) <= 500
        if value == True:
            main['배움터(500)'][i] += int(value)
        else:
            pass
main
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#        자치구            동           시설명                        주소      연면적  \
# 0.0    종로구        청운효자동    청운효자동 주민센터         서울특별시 종로구 자하문로 92   965.52
# 1.0    종로구          사직동      사직동 주민센터         서울특별시 종로구 사직로9길 1   346.65
# 2.0    종로구  종로1.2.3.4가동  종로1-4가동 주민센터         서울특별시 종로구 종로17길 8  1981.09
# 3.0    종로구          삼청동      삼청동 주민센터         서울특별시 종로구 삼청로 107    998.1
# 4.0    종로구          가회동      가회동 주민센터          서울특별시 종로구 북촌로 35  1032.08
# ...    ...          ...           ...                       ...      ...
# 504.0  강동구         천호2동       해공노인복지관    서울특별시 강동구 천중로17길 42-16      598
# 505.0  성북구          삼선동      삼선실버복지센터      서울특별시 성북구 삼선교로18길 41   542.11
# ...

# %%
# 병원 UTMK 데이터 가져오기
hospital = pd.read_excel('/content/drive/MyDrive/시소프로젝트/NEW(공모전용)/대중교통, 주변특성 데이터/병원 UTMK변환.xlsx',index_col =0)
hospital.head(1)
# Out:
#           위도          경도        위도UTMK         경도UTMK
# 0  37.528592  126.863614  1.947582e+06  943960.198502

# %%
a1 = hospital['위도UTMK']
a1.head(1)
# Out:
# 0    1.947582e+06
# Name: 위도UTMK, dtype: float64

# %%
a2 = hospital['경도UTMK']
a2.head(1)
# Out:
# 0    943960.198502
# Name: 경도UTMK, dtype: float64

# %%
main["병원(500)"] = 0
main.head(3)
# Out:
#      자치구            동           시설명                 주소      연면적         위도  \
# 0.0  종로구        청운효자동    청운효자동 주민센터  서울특별시 종로구 자하문로 92   965.52  37.584083
# 1.0  종로구          사직동      사직동 주민센터  서울특별시 종로구 사직로9길 1   346.65  37.576191
# 2.0  종로구  종로1.2.3.4가동  종로1-4가동 주민센터  서울특별시 종로구 종로17길 8  1981.09  37.570728
#
#              경도        위도UTMK         경도UTMK  도서관(500)  배움터(500)  병원(500)
# 0.0  126.970636  1.953680e+06  953451.030567         0         0        0
# 1.0  126.968829  1.952806e+06  953286.588072         2         0        0
# 2.0  126.988912  1.952190e+06  955056.678912         0         2        0

# %%
for i in range(len(main)):
    for j in range(len(hospital)):
        value = False
        value = np.sqrt((x[i] - a1[j])**2 + (y[i] - a2[j])**2) <= 500
        if value == True:
            main['병원(500)'][i] += int(value)
        else:
            pass
main
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#        자치구            동           시설명                        주소      연면적  \
# 0.0    종로구        청운효자동    청운효자동 주민센터         서울특별시 종로구 자하문로 92   965.52
# 1.0    종로구          사직동      사직동 주민센터         서울특별시 종로구 사직로9길 1   346.65
# 2.0    종로구  종로1.2.3.4가동  종로1-4가동 주민센터         서울특별시 종로구 종로17길 8  1981.09
# 3.0    종로구          삼청동      삼청동 주민센터         서울특별시 종로구 삼청로 107    998.1
# 4.0    종로구          가회동      가회동 주민센터          서울특별시 종로구 북촌로 35  1032.08
# ...    ...          ...           ...                       ...      ...
# 504.0  강동구         천호2동       해공노인복지관    서울특별시 강동구 천중로17길 42-16      598
# 505.0  성북구          삼선동      삼선실버복지센터      서울특별시 성북구 삼선교로18길 41   542.11
# ...

# %%
# 공원 UTMK 데이터 가져오기 
park = pd.read_excel('/content/drive/MyDrive/시소프로젝트/NEW(공모전용)/대중교통, 주변특성 데이터/서울공원 위도경도 변환.xlsx',index_col =0)
park = park.iloc[:,20:]
park.head(1)
# Out:
#            위도UTMK         경도UTMK
# 0.0  1.949905e+06  955173.699701

# %%
a1 = park['위도UTMK']
a1.head(1)
# Out:
# 0.0    1.949905e+06
# Name: 위도UTMK, dtype: float64

# %%
a2 = park['경도UTMK']
a2.head(1)
# Out:
# 0.0    955173.699701
# Name: 경도UTMK, dtype: float64

# %%
main["공원(500)"] = 0
main.head(3)
# Out:
#      자치구            동           시설명                 주소      연면적         위도  \
# 0.0  종로구        청운효자동    청운효자동 주민센터  서울특별시 종로구 자하문로 92   965.52  37.584083
# 1.0  종로구          사직동      사직동 주민센터  서울특별시 종로구 사직로9길 1   346.65  37.576191
# 2.0  종로구  종로1.2.3.4가동  종로1-4가동 주민센터  서울특별시 종로구 종로17길 8  1981.09  37.570728
#
#              경도        위도UTMK         경도UTMK  도서관(500)  배움터(500)  병원(500)  \
# 0.0  126.970636  1.953680e+06  953451.030567         0         0        0
# 1.0  126.968829  1.952806e+06  953286.588072         2         0        0
# 2.0  126.988912  1.952190e+06  955056.678912         0         2        1
#
#      공원(500)
# 0.0        0
# 1.0        0
# 2.0        0

# %%
for i in range(len(main)):
    for j in range(len(park)):
        value = False
        value = np.sqrt((x[i] - a1[j])**2 + (y[i] - a2[j])**2) <= 500
        if value == True:
            main['공원(500)'][i] += int(value)
        else:
            pass
main
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#        자치구            동           시설명                        주소      연면적  \
# 0.0    종로구        청운효자동    청운효자동 주민센터         서울특별시 종로구 자하문로 92   965.52
# 1.0    종로구          사직동      사직동 주민센터         서울특별시 종로구 사직로9길 1   346.65
# 2.0    종로구  종로1.2.3.4가동  종로1-4가동 주민센터         서울특별시 종로구 종로17길 8  1981.09
# 3.0    종로구          삼청동      삼청동 주민센터         서울특별시 종로구 삼청로 107    998.1
# 4.0    종로구          가회동      가회동 주민센터          서울특별시 종로구 북촌로 35  1032.08
# ...    ...          ...           ...                       ...      ...
# 504.0  강동구         천호2동       해공노인복지관    서울특별시 강동구 천중로17길 42-16      598
# 505.0  성북구          삼선동      삼선실버복지센터      서울특별시 성북구 삼선교로18길 41   542.11
# ...

# %% [markdown]
# ## 대중교통 개수 찾기 시작

# %%
bus = pd.read_excel('/content/drive/MyDrive/시소프로젝트/NEW(공모전용)/대중교통, 주변특성 데이터/서울 버스정류장.xlsx',index_col =0)
bus.head(1)
# Out:
#    ARS-ID     정류소명        X좌표        Y좌표        위도UTMK         경도UTMK
# 0    1001  종로2가사거리  126.98775  37.569765  1.952083e+06  954953.448869

# %%
a1 = bus['위도UTMK']
a1.head(1)
# Out:
# 0    1.952083e+06
# Name: 위도UTMK, dtype: float64

# %%
a2 = bus['경도UTMK']
a2.head(1)
# Out:
# 0    954953.448869
# Name: 경도UTMK, dtype: float64

# %%
main["버스(100)"] = 0
main.head(3)
# Out:
#      자치구            동           시설명                 주소      연면적         위도  \
# 0.0  종로구        청운효자동    청운효자동 주민센터  서울특별시 종로구 자하문로 92   965.52  37.584083
# 1.0  종로구          사직동      사직동 주민센터  서울특별시 종로구 사직로9길 1   346.65  37.576191
# 2.0  종로구  종로1.2.3.4가동  종로1-4가동 주민센터  서울특별시 종로구 종로17길 8  1981.09  37.570728
#
#              경도        위도UTMK         경도UTMK  도서관(500)  배움터(500)  병원(500)  \
# 0.0  126.970636  1.953680e+06  953451.030567         0         0        0
# 1.0  126.968829  1.952806e+06  953286.588072         2         0        0
# 2.0  126.988912  1.952190e+06  955056.678912         0         2        1
#
#      공원(500)  버스(100)
# 0.0        0        0
# 1.0        1        0
# 2.0        1        0

# %%
for i in range(len(main)):
    for j in range(len(bus)):
        value = False
        value = np.sqrt((x[i] - a1[j])**2 + (y[i] - a2[j])**2) <= 100
        if value == True:
            main['버스(100)'][i] += int(value)
        else:
            pass
main
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#        자치구            동           시설명                        주소      연면적  \
# 0.0    종로구        청운효자동    청운효자동 주민센터         서울특별시 종로구 자하문로 92   965.52
# 1.0    종로구          사직동      사직동 주민센터         서울특별시 종로구 사직로9길 1   346.65
# 2.0    종로구  종로1.2.3.4가동  종로1-4가동 주민센터         서울특별시 종로구 종로17길 8  1981.09
# 3.0    종로구          삼청동      삼청동 주민센터         서울특별시 종로구 삼청로 107    998.1
# 4.0    종로구          가회동      가회동 주민센터          서울특별시 종로구 북촌로 35  1032.08
# ...    ...          ...           ...                       ...      ...
# 504.0  강동구         천호2동       해공노인복지관    서울특별시 강동구 천중로17길 42-16      598
# 505.0  성북구          삼선동      삼선실버복지센터      서울특별시 성북구 삼선교로18길 41   542.11
# ...

# %%
sandwich = pd.read_excel('/content/drive/MyDrive/시소프로젝트/NEW(공모전용)/대중교통, 주변특성 데이터/서울시 지하철역 위치.xlsx',index_col =0)
sandwich.head(1)
# Out:
#    역사_ID 역사명   호선          위도         경도        위도UTMK         경도UTMK
# 0   9996  미사  5호선  127.193877  37.560927  1.951024e+06  973153.163495

# %%
a1 = sandwich['위도UTMK']
a1.head(1)
# Out:
# 0    1.951024e+06
# Name: 위도UTMK, dtype: float64

# %%
a2 = sandwich['경도UTMK']
a2.head(1)
# Out:
# 0    973153.163495
# Name: 경도UTMK, dtype: float64

# %%
main["지하철(250)"] = 0
main.head(3)
# Out:
#      자치구            동           시설명                 주소      연면적         위도  \
# 0.0  종로구        청운효자동    청운효자동 주민센터  서울특별시 종로구 자하문로 92   965.52  37.584083
# 1.0  종로구          사직동      사직동 주민센터  서울특별시 종로구 사직로9길 1   346.65  37.576191
# 2.0  종로구  종로1.2.3.4가동  종로1-4가동 주민센터  서울특별시 종로구 종로17길 8  1981.09  37.570728
#
#              경도        위도UTMK         경도UTMK  도서관(500)  배움터(500)  병원(500)  \
# 0.0  126.970636  1.953680e+06  953451.030567         0         0        0
# 1.0  126.968829  1.952806e+06  953286.588072         2         0        0
# 2.0  126.988912  1.952190e+06  955056.678912         0         2        1
#
#      공원(500)  버스(100)  지하철(250)
# 0.0        0        1         0
# 1.0        1        1         0
# 2.0        1        4         0

# %%
for i in range(len(main)):
    for j in range(len(sandwich)):
        value = False
        value = np.sqrt((x[i] - a1[j])**2 + (y[i] - a2[j])**2) <= 250
        if value == True:
            main['지하철(250)'][i] += int(value)
        else:
            pass
main
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#        자치구            동           시설명                        주소      연면적  \
# 0.0    종로구        청운효자동    청운효자동 주민센터         서울특별시 종로구 자하문로 92   965.52
# 1.0    종로구          사직동      사직동 주민센터         서울특별시 종로구 사직로9길 1   346.65
# 2.0    종로구  종로1.2.3.4가동  종로1-4가동 주민센터         서울특별시 종로구 종로17길 8  1981.09
# 3.0    종로구          삼청동      삼청동 주민센터         서울특별시 종로구 삼청로 107    998.1
# 4.0    종로구          가회동      가회동 주민센터          서울특별시 종로구 북촌로 35  1032.08
# ...    ...          ...           ...                       ...      ...
# 504.0  강동구         천호2동       해공노인복지관    서울특별시 강동구 천중로17길 42-16      598
# 505.0  성북구          삼선동      삼선실버복지센터      서울특별시 성북구 삼선교로18길 41   542.11
# ...

# %%
# 엑셀로 저장
# main.to_excel('주민센터 - 주변특성 + 대중교통.xlsx')

# %% [markdown]
# # merge

# %% [markdown]
# - main(주민센터, 주변특성, 대중교통, 연면적, 위경도) - 자치구, 동 -
# - people(인구변수) - 구, 동 -
# - final_df(동이름, 디지털 정보 지수) - 동, 디지털 정보 지수 -

# %%
main = pd.read_excel('/content/drive/MyDrive/시소프로젝트/NEW(공모전용)/전처리용/주민센터 - 주변특성 + 대중교통.xlsx', index_col=0)

# %%
main.head()
# Out:
#      자치구            동           시설명                 주소      연면적         위도  \
# 0.0  종로구        청운효자동    청운효자동 주민센터  서울특별시 종로구 자하문로 92   965.52  37.584083
# 1.0  종로구          사직동      사직동 주민센터  서울특별시 종로구 사직로9길 1   346.65  37.576191
# 2.0  종로구  종로1.2.3.4가동  종로1-4가동 주민센터  서울특별시 종로구 종로17길 8  1981.09  37.570728
# 3.0  종로구          삼청동      삼청동 주민센터  서울특별시 종로구 삼청로 107    998.1  37.584979
# 4.0  종로구          가회동      가회동 주민센터   서울특별시 종로구 북촌로 35  1032.08  37.580025
#
#              경도        위도UTMK         경도UTMK  도서관(500)  배움터(500)  병원(500)  \
# 0.0  126.970636  1.953680e+06  953451.030567       0.0       0.0      0.0
# 1.0  126.968829  1.952806e+06  953286.588072       2.0       0.0      0.0
# 2.0  126.988912  1.952190e+06  955056.678912       0.0       2.0      1.0
# 3.0  126.981782  1.953774e+06  954435.679506       1.0       0.0      0.0
# 4.0  126.984805  1.953223e+06  954699.580385       1.0       0.0      0.0
#
#      공원(500)  버스(100)  지하철(250)
# 0.0      0.0      1.0       0.0
# ...

# %%
main.shape
# Out:
# (509, 15)

# %%
people.head()
# Out:
#    시군구    동  동별전체인구  60세~  60세~/전체인구  구별전체인구  60세~/구별전체          보행인구  \
# 0  종로구  사직동    9372  2468   0.263338   39120   0.063088  4.474791e+06
# 1  종로구  삼청동    2456   827   0.336726   39120   0.021140  4.474791e+06
# 2  종로구  부암동    9579  2558   0.267042   39120   0.065389  4.474791e+06
# 3  종로구  평창동   18152  4937   0.271981   39120   0.126201  4.474791e+06
# 4  종로구  무악동    8259  2006   0.242887   39120   0.051278  4.474791e+06
#
#               비율
# 0  282305.293147
# 1   94597.438184
# 2  292600.056687
# 3  564724.972591
# 4  229458.840382

# %%
people.shape
# Out:
# (425, 9)

# %%
people.rename(columns={'시군구' : '자치구'}, inplace=True)

# %%
final_df = pd.read_excel('/content/drive/MyDrive/시소프로젝트/NEW(공모전용)/전처리용/동별 디지털정보지수(50~).xlsx', index_col=0)

# %%
final_df.head()
# Out:
#        동  디지털정보지수
# 0.0  사직동  2406.94
# 1.0  삼청동   680.87
# 2.0  부암동  2589.79
# 3.0  평창동  5073.30
# 4.0  무악동  2145.94

# %%
main_df = pd.merge(main, people, how='left',on=['자치구', '동'])
main_df
# Out:
#      자치구            동           시설명                        주소      연면적  \
# 0    종로구        청운효자동    청운효자동 주민센터         서울특별시 종로구 자하문로 92   965.52
# 1    종로구          사직동      사직동 주민센터         서울특별시 종로구 사직로9길 1   346.65
# 2    종로구  종로1.2.3.4가동  종로1-4가동 주민센터         서울특별시 종로구 종로17길 8  1981.09
# 3    종로구          삼청동      삼청동 주민센터         서울특별시 종로구 삼청로 107    998.1
# 4    종로구          가회동      가회동 주민센터          서울특별시 종로구 북촌로 35  1032.08
# ..   ...          ...           ...                       ...      ...
# 504  강동구         천호2동       해공노인복지관    서울특별시 강동구 천중로17길 42-16      598
# 505  성북구          삼선동      삼선실버복지센터      서울특별시 성북구 삼선교로18길 41   542.11
# 506  금천구         독산1동   금천한내어르신복지센터       서울특별시 금천구 한내로 69-15     2003
# 507  서초구         방배3동      방배느티나무쉼터  서울특별시 서초구 남부순환로287길 17-4    519.5
# 508  성동구          용답동       삼성시니어센터       서울특별시 성동구 용답동 72-17  1716.38
#
#             위도          경도        위도UTMK         경도UTMK  도서관(500)  ...  \
# ...

# %%
main_df.shape
# Out:
# (509, 22)

# %%
main_df = pd.merge(main_df, final_df, how='left',on=['동'])

# %%
main_df.isnull().sum()
# Out:
# 자치구          0
# 동            0
# 시설명          0
# 주소           0
# 연면적          0
# 위도           0
# 경도           0
# 위도UTMK       0
# 경도UTMK       0
# 도서관(500)     0
# 배움터(500)     0
# 병원(500)      0
# 공원(500)      0
# 버스(100)      0
# 지하철(250)     0
# 동별전체인구       0
# 60세~         0
# 60세~/전체인구    0
# 구별전체인구       0
# 60세~/구별전체    0
# 보행인구         0
# 비율           0
# 디지털정보지수      0
# dtype: int64

# %%
main_df[main_df['동']=='신사동']
# Out:
#      자치구    동        시설명                   주소      연면적         위도          경도  \
# 335  관악구  신사동   신사동 주민센터    서울특별시 관악구 조원로 142     1940  37.485419  126.918117
# 336  관악구  신사동   신사동 주민센터    서울특별시 관악구 조원로 142     1940  37.485419  126.918117
# 370  강남구  신사동   신사동 주민센터   서울특별시 강남구 압구정로 128  1722.81  37.523980  127.022827
# 371  강남구  신사동   신사동 주민센터   서울특별시 강남구 압구정로 128  1722.81  37.523980  127.022827
# 499  강남구  신사동  압구정노인복지센터  서울특별시 강남구 도산대로53길 5      793  37.524309  127.038532
# 500  강남구  신사동  압구정노인복지센터  서울특별시 강남구 도산대로53길 5      793  37.524309  127.038532
#
#            위도UTMK         경도UTMK  도서관(500)  ...  버스(100)  지하철(250)  동별전체인구  \
# 335  1.942761e+06  948746.439131       0.0  ...      1.0       0.0   22560
# 336  1.942761e+06  948746.439131       0.0  ...      1.0       0.0   22560
# 370  1.946988e+06  958025.409467       0.0  ...      1.0       0.0   15993
# 371  1.946988e+06  958025.409467       0.0  ...      1.0       0.0   15993
# ...

# %%
# 관악구과 강남구에 동이름이 동일한 곳이 존재
# 위치가 신사동인 곳은 두개씩 merge가 되었기때문에 행삭제 처리
main_df.drop(index=[336, 370, 499], axis=0, inplace=True)

# %%
main_df
# Out:
#      자치구            동           시설명                        주소      연면적  \
# 0    종로구        청운효자동    청운효자동 주민센터         서울특별시 종로구 자하문로 92   965.52
# 1    종로구          사직동      사직동 주민센터         서울특별시 종로구 사직로9길 1   346.65
# 2    종로구  종로1.2.3.4가동  종로1-4가동 주민센터         서울특별시 종로구 종로17길 8  1981.09
# 3    종로구          삼청동      삼청동 주민센터         서울특별시 종로구 삼청로 107    998.1
# 4    종로구          가회동      가회동 주민센터          서울특별시 종로구 북촌로 35  1032.08
# ..   ...          ...           ...                       ...      ...
# 507  강동구         천호2동       해공노인복지관    서울특별시 강동구 천중로17길 42-16      598
# 508  성북구          삼선동      삼선실버복지센터      서울특별시 성북구 삼선교로18길 41   542.11
# 509  금천구         독산1동   금천한내어르신복지센터       서울특별시 금천구 한내로 69-15     2003
# 510  서초구         방배3동      방배느티나무쉼터  서울특별시 서초구 남부순환로287길 17-4    519.5
# 511  성동구          용답동       삼성시니어센터       서울특별시 성동구 용답동 72-17  1716.38
#
#             위도          경도        위도UTMK         경도UTMK  도서관(500)  ...  \
# ...

# %%
main_df.to_excel('main_seoul_senior_data.xlsx', index=False)
